# %% [markdown]
# # JSON and APIs
#
# _November 3, 2020_
#
# Agenda today:
# - Introduction to API and Remote Server Model
# - Getting data through an API: Case study with YELP API

# %%
import pandas as pd
import numpy as np
import requests
import json
#from yelp.client import Client
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %% [markdown]
# ## Part I. APIs and Remote Server Model
# API stands for Application Programming Interface. At some point or the other, large companies would build API for their products for their clients or internal use. It allows the company's application to communicate with another application. But what _exactly_ is an API?
#
# #### Remote server
# When we think about the world of Web, we can think of it as a collection of _servers_. And servers are nothing but huge computers that store a huge amount of data from users and are optimized to process requests. For example, when you type in www.facebook.com, your browser sends a _request_ to the Facebook server, and gets a response from the server, thus interpreting the code and displaying your homepage.
#
# In this case, your browser is the _client_, and Facebook’s server is an API. To put it broadly, whenever you visit a website, you are interacting with its API. However, an API isn’t the same as the remote server — rather it is the part of the server that receives __requests__ and sends __responses__.
#
# <img src='status-code.png' width = 500>

# %% [markdown]
# ## Part II. Getting Data Through APIs
#
# The `get()` method send a request to YELP's API, and stored information in a variable called `request`. Next, let's see if it's successful.

# %% [markdown]
# #### YELP API
# Sometimes you need _authentication_ to get data from a service in additional to just sending a `GET()` request. Yelp API is a perfect example.
#
# You will need to go to the YELP's developer's [website](https://www.yelp.com/developers/v3/manage_app) and request for a client ID and API key, which function like a key into a house of data.
#
# <img src='yelp.png' width = 500>

# %%
# lets try to get some data from yelp!
url = 'https://api.yelp.com/v3/businesses/search'
response = requests.get(url)

# %%
# check the status code
# response.status_code

# what happened here?
# Out:
# 400

# %%
# now we are ready to get our data 

# usually, services would limit you to a certain amount of API calls. This varies from service
# to service, so you have to watch out to it 

MY_API_KEY = "voF1zfOhwzfP5UJAIJRMSwmxcHM7hI89wuTFosmijoL3FkbW6q25y5ihn21bHCuZC3MGXanPvFQYzkCqT6YuUL2pqKKx_L8TUibPcevpDB6ECGWYC1_SsV_Fvp6hX3Yx"




term = 'Pizza'
location = 'New Jersey'
SEARCH_LIMIT = 45

url = 'https://api.yelp.com/v3/businesses/search'

headers = {
        'Authorization': 'Bearer {}'.format(MY_API_KEY),
    }

url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
response = requests.get(url, headers=headers, params=url_params)

# %%
response.status_code
# Out:
# 200

# %%
# examine the response object

print(response)
# Out:
# <Response [200]>

# %%
# how are we going to parse the response.text object?

response.text
# Out:
# '{"businesses": [{"id": "0E089bWgJvUl396T693rYg", "alias": "mercato-tomato-pie-newark", "name": "Mercato Tomato Pie", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/bn-1edtiYhTGivrf8tkcog/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/mercato-tomato-pie-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg", "review_count": 288, "categories": [{"alias": "pizza", "title": "Pizza"}, {"alias": "italian", "title": "Italian"}], "rating": 4.0, "coordinates": {"latitude": 40.73486, "longitude": -74.17068}, "transactions": ["delivery", "pickup"], "price": "$$", "location": {"address1": "212 Market St", "address2": "", "address3": "", "city": "Newark", "zip_code": "07102", "country": "US", "state": "NJ", "display_address": ["212 Market St", "Newark, NJ 07102"]}, "phone": "+19734249000", "display_phone": "(973) 424-9000", "distance": 101.15684275311548}, {"id": "mjVdcG2QpR3_Ww_gYP8yCg", "alias": "roberts-pizzeria-newark-3", "name": "Robert\'s Pizzeria", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/UyJu1aOs_LvLh0uBruTXBg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/roberts-pizzeria-newark-3?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg", "review_count": 86, "categories": [{"alias": "pizza", "title": "Pizza"}, {"alias": "italian", "title": "Italian"}], "rating": 4.0, "coordinates": {"latitude": 40.7408097, "longitude": -74.1723118}, "transactions": ["delivery", "pickup"], "price": "$", "location": {"address1": "63 New St", "address2": "", "address3": "", "city": "Newark", "zip_code": "07102", "country": "US", "state": "NJ", "display_address": ["63 New St", "Newark, NJ 07102"]}, "phone": "+19736420082", "display_phone": "(973) 642-0082", "distance": 616.4546799488285}, {"id": "Oh5PRqcZxYN8yH4I0_xWJQ", "alias": "queen-pizza-ii-newark", "name": "Queen Pizza II", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/v5C5o03vWNsounepmNSBHg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/queen-pizza-ii-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg", "review_count": 22, "categories": [{"alias": "italian", "title": "Italian"}, {"alias": "pizza", "title": "Pizza"}], "rating": 4.0, "coordinates": {"latitude": 40.7362442016602, "longitude": -74.1692657470703}, "transactions": ["delivery", "pickup"], "price": "$", "location": {"address1": "48 Commerce St", "address2": null, "address3": null, "city": "Newark", "zip_code": "07102", "country": "US", "state": "NJ", "display_address": ["48 Commerce St", "Newark, NJ 07102"]}, "phone": "+19732421829", "display_phone": "(973) 242-1829", "distance": 235.0203744137755}, {"id": "esNmc5qDddtI_Uzkb_yZYQ", "alias": "blaze-pizza-newark-2", "name": "Blaze Pizza", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/M4zzQ3DN9PBf_PGL3Qu53Q/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/blaze-pizza-newark-2?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg", "review_count": 217, "categories": [{"alias": "salad", "title": "Salad"}, {"alias": "pizza", "title": "Pizza"}, {"alias": "hotdogs", "title": "Fast Food"}], "rating": 4.0, "coordinates": {"latitude": 40.7382702827454, "longitude": -74.1707014292479}, "transactions": [], "price": "$", "location": {"address1": "691 Broad St", "address2": null, "address3": null, "city": "Newark", "zip_code": "07102", "country": "US", "state": "NJ", "display_address": ["691 Broad St", "Newark, NJ 07102"]}, "phone": "+19732064278", "display_phone": "(973) 206-4278", "distance": 357.9144778163163}, {"id": "OQAUrJMdH7PIVp18dnBf_A", "alias": "mulberry-street-pizza-newark-3", "name": "Mulberry Street Pizza", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/s7ISvp2-2Hti3Mmw5 ...

# %%
# json.load()

json.loads(response.text)
# Out:
# {'businesses': [{'id': 'X0DNGKUQPjf0AfaXfXU2Qg',
#    'alias': 'kick-axe-throwing-brooklyn-2',
#    'name': 'Kick Axe Throwing',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WjKylwrUBKnGIE_ldj142Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kick-axe-throwing-brooklyn-2?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 404,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'axethrowing', 'title': 'Axe Throwing'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6790268, 'longitude': -73.983077},
#    'transactions': [],
#    'location': {'address1': '622 Degraw St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['622 Degraw St', 'Brooklyn, NY 11217']},
#    'phone': '+18335425293',
#    'display_phone': '(833) 542-5293',
#    'distance': 4733.616620254917},
#   {'id': '4E6BkrEVf_0TjRVYE7gxeQ',
#    'alias': 'bury-the-hatchet-brooklyn-axe-throwing-brooklyn-2',
#    'name': 'Bury the Hatchet Brooklyn - Axe Throwing',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SH8_Nwmd13LkntwuzcEPeg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bury-the-hatchet-brooklyn-axe-throwing-brooklyn-2?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 155,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'},
#     {'alias': 'teambuilding', 'title': 'Team Building Activities'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7283195, 'longitude': -73.9600679},
#    'transactions': [],
#    'location': {'address1': '25 Noble St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['25 Noble St', 'Brooklyn, NY 11222']},
#    'phone': '+19172439696',
#    'display_phone': '(917) 243-9696',
#    'distance': 8652.979400045351},
#   {'id': 'PhEkSzYZHKYS7uyXePmkMw',
#    'alias': 'axes-and-arrows-long-island-city-2',
#    'name': 'Axes And Arrows',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Uinh_osn8ykDeLoigmgo0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/axes-and-arrows-long-island-city-2?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 49,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'},
#     {'alias': 'archery', 'title': 'Archery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7425127, 'longitude': -73.933816},
#    'transactions': [],
#    'location': {'address1': '47- 11 Van Dam St',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47- 11 Van Dam St', 'Long Island City, NY 11101']},
#    'phone': '+17183619152',
#    'display_phone': '(718) 361-9152',
#    'distance': 9996.588059135383},
#   {'id': '4sPiNeQGD8mzt9ess7xZrQ',
#    'alias': 'mad-axe-brooklyn',
#    'name': 'Mad Axe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UOC-BswrAMfq9dX6MXxa8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mad-axe-brooklyn?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 13,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.707, 'longitude': -73.93364},
#    'transactions': [],
#    'location': {'address1': '94 Bogart Street 2nd',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['94 Bogart Street 2nd', 'Brooklyn, NY 11206']},
#    'phone': '+19292950229',
#    'display_phone': '(929) 295-0229',
#    'distance': 6101.731538019727},
#   {'id': 'lZVE27r_W_3GXxNwECYC4g',
#    'alias': 'live-axe-new-york',
#    'name': 'Live Axe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-Z1qvni_2N-K85FHmaesaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/live-axe-new-york?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 7,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71769, 'longitude': -74.00144},
#    'transactions': [],
#    'location': {'address1': '96 Lafayette St',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['96 Lafayette St', 'New York, NY 10013']},
#    'phone': '+18888129060',
#    'display_phone': '(888) 812-9060',
#    'distance': 8955.976101576549},
#   {'id': 'b9DAbR-1eIfLr6TPI_r59Q',
#    'alias': 'axe-kicking-entertainment-mineola',
#    'name': 'Axe Kicking Entertainment',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bBooTB1Ja2PSGTGLhbAjVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/axe-kicking-entertainment-mineola?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 7,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'},
#     {'alias': 'archery', 'title': 'Archery'},
#     {'alias': 'bowling', 'title': 'Bowling'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74638, 'longitude': -73.65027},
#    'transactions': [],
#    'location': {'address1': '360 Jericho Turnpike',
#     'address2': None,
#     'address3': '',
#     'city': 'Mineola',
#     'zip_code': '11501',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['360 Jericho Turnpike', 'Mineola, NY 11501']},
#    'phone': '+15162806040',
#    'display_phone': '(516) 280-6040',
#    'distance': 26518.825160012875},
#   {'id': 'Ub7igTH4-w5haq_bHmvFjQ',
#    'alias': 'hatchets-and-hops-brooklyn',
#    'name': 'Hatchets & Hops',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XfyHGdIjuF3dufr1NgMqBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hatchets-and-hops-brooklyn?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 1,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.721237, 'longitude': -73.957603},
#    'transactions': [],
#    'location': {'address1': '98 North 11th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['98 North 11th St', 'Brooklyn, NY 11249']},
#    'phone': '+18559512973',
#    'display_phone': '(855) 951-2973',
#    'distance': 7814.584675164627},
#   {'id': 'K_Jm8V-XuOFlbHb_VUzk-w',
#    'alias': 'indoor-extreme-sports-long-island-city',
#    'name': 'Indoor Extreme Sports',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wQE-gOKf-shCB4sDI2WmhQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/indoor-extreme-sports-long-island-city?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 509,
#    'categories': [{'alias': 'paintball', 'title': 'Paintball'},
#     {'alias': 'lasertag', 'title': 'Laser Tag'},
#     {'alias': 'axethrowing', 'title': 'Axe Throwing'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7422746, 'longitude': -73.9338804},
#    'transactions': [],
#    'location': {'address1': '47 11 Van Dam St',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47 11 Van Dam St', 'Long Island City, NY 11101']},
#    'phone': '+17183619152',
#    'display_phone': '(718) 361-9152',
#    'distance': 10012.024588128},
#   {'id': 'yXOjBSwyqOKDY7oHx3z7HA',
#    'alias': 'tomahawks-jersey-city',
#    'name': 'Tomahawks',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AcR-ExIWOWPNXRr6G5cGQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tomahawks-jersey-city?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 14,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7411216, 'longitude': -74.0493572},
#    'transactions': [],
#    'location': {'address1': '7 Sherman Ave',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'Jersey City',
#     'zip_code': '07307',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['7 Sherman Ave', 'Fl 2', 'Jersey City, NJ 07307']},
#    'phone': '+12014209722',
#    'display_phone': '(201) 420-9722',
#    'distance': 13556.0314007906},
#   {'id': 'wuy6jyi5cxm1pwnUTWyBLw',
#    'alias': 'stumpys-hatchet-house-fairfield-fairfield-3',
#    'name': "Stumpy's Hatchet House - Fairfield",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yKG858jIoenW0jLpq6Hg1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stumpys-hatchet-house-fairfield-fairfield-3?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 45,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'},
#     {'alias': 'recreation', 'title': 'Recreation Centers'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.882466, 'longitude': -74.2942046508915},
#    'transactions': [],
#    'location': {'address1': '373 US-46 W',
#     'address2': 'Ste D140',
#     'address3': '',
#     'city': 'Fairfield',
#     'zip_code': '07004',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['373 US-46 W', 'Ste D140', 'Fairfield, NJ 07004']},
#    'phone': '+19737213120',
#    'display_phone': '(973) 721-3120',
#    'distance': 39342.64728763023},
#   {'id': 'oKkn9nKh6jB-fsQIDbP4tQ',
#    'alias': 'bury-the-hatchet-matawan',
#    'name': 'Bury The Hatchet',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EsKEUTyvjjzdr6SzTzubSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bury-the-hatchet-matawan?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 91,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'},
#     {'alias': 'teambuilding', 'title': 'Team Building Activities'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.4234040521118,
#     'longitude': -74.2643531039357},
#    'transactions': [],
#    'location': {'address1': '419 Route 34',
#     'address2': '',
#     'address3': None,
#     'city': 'Matawan',
#     'zip_code': '07747',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['419 Route 34', 'Matawan, NJ 07747']},
#    'phone': '+17329626284',
#    'display_phone': '(732) 962-6284',
#    'distance': 37446.224760844736},
#   {'id': 'xC9gtq17G9XU5d-yjkprfA',
#    'alias': 'bury-the-hatchet-paramus-axe-throwing-paramus-2',
#    'name': 'Bury the Hatchet Paramus - Axe Throwing',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2z7jvctXJEeKUBKB-XIPSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bury-the-hatchet-paramus-axe-throwing-paramus-2?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 75,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.9486345940514,
#     'longitude': -74.0677446595245},
#    'transactions': [],
#    'location': {'address1': '49 E Midland Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Paramus',
#     'zip_code': '07652',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['49 E Midland Ave', 'Paramus, NJ 07652']},
#    'phone': '+12016883358',
#    'display_phone': '(201) 688-3358',
#    'distance': 34674.4395003575},
#   {'id': '1BUoVTCYSpGfG0oobAr5Hg',
#    'alias': 'bury-the-hatchet-axe-throwing-bloomfield-bloomfield',
#    'name': 'Bury The Hatchet Axe Throwing- Bloomfield',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Y6OdaWjNZKFNKuSdl-rU3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bury-the-hatchet-axe-throwing-bloomfield-bloomfield?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 91,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.79607, 'longitude': -74.2003299},
#    'transactions': [],
#    'location': {'address1': '672 Bloomfield Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Bloomfield',
#     'zip_code': '07003',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['672 Bloomfield Ave', 'Bloomfield, NJ 07003']},
#    'phone': '+19738427725',
#    'display_phone': '(973) 842-7725',
#    'distance': 27173.957270887662},
#   {'id': '5izrkxTF_OWgwEdgzjNCAA',
#    'alias': 'bury-the-hatchet-woodbridge-axe-throwing-avenel',
#    'name': 'Bury The Hatchet Woodbridge - Axe Throwing',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZhVxhmy3BDOGaEwflbF9RA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bury-the-hatchet-woodbridge-axe-throwing-avenel?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 8,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.5919, 'longitude': -74.28943},
#    'transactions': [],
#    'location': {'address1': '1600 St Georges Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Avenel',
#     'zip_code': '07001',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1600 St Georges Ave', 'Avenel, NJ 07001']},
#    'phone': '+17322986614',
#    'display_phone': '(732) 298-6614',
#    'distance': 30246.00489811494},
#   {'id': 'BOYnPH11OTCMPzxiPJXHpw',
#    'alias': 'hatchet-house-hackensack-3',
#    'name': 'Hatchet House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1BayJ29kv-F92Dqy7uboDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hatchet-house-hackensack-3?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 1,
#    'categories': [{'alias': 'axethrowing', 'title': 'Axe Throwing'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'paintball', 'title': 'Paintball'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.8832357904038,
#     'longitude': -74.0432552620768},
#    'transactions': [],
#    'location': {'address1': '157A Main St',
#     'address2': '',
#     'address3': None,
#     'city': 'Hackensack',
#     'zip_code': '07601',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['157A Main St', 'Hackensack, NJ 07601']},
#    'phone': '+18332934653',
#    'display_phone': '(833) 293-4653',
#    'distance': 27125.32070094518},
#   {'id': 'LN1itZNPsylqInDsLG4M_g',
#    'alias': 'new-york-sports-clubs-new-york-73',
#    'name': 'New York Sports Clubs',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eMLTokizDk84J50jB3gmzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-york-sports-clubs-new-york-73?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 105,
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'},
#     {'alias': 'sports_clubs', 'title': 'Sports Clubs'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.7455891, 'longitude': -73.9980521},
#    'transactions': [],
#    'location': {'address1': '270 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['270 8th Ave', 'New York, NY 10011']},
#    'phone': '+12122433400',
#    'display_phone': '(212) 243-3400',
#    'distance': 11489.778200039469},
#   {'id': '0OJWRkAI-iot-dtKX6BjbQ',
#    'alias': 'queens-archery-flushing',
#    'name': 'Queens Archery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lXOzZPUHPPdu8iGsaH38nA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/queens-archery-flushing?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 363,
#    'categories': [{'alias': 'sports_clubs', 'title': 'Sports Clubs'},
#     {'alias': 'archery', 'title': 'Archery'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76137, 'longitude': -73.79556},
#    'transactions': [],
#    'location': {'address1': '170-20 39th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11358',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['170-20 39th Ave', 'Flushing, NY 11358']},
#    'phone': '+17184611756',
#    'display_phone': '(718) 461-1756',
#    'distance': 17134.395523061943}],
#  'total': 27,
#  'region': {'center': {'longitude': -73.93936157226562,
#    'latitude': 40.652330148320374}}}

# %%
# working with JSON

pizza = response.text
pizza = json.loads(pizza)

# %%
pizza
# Out:
# {'businesses': [{'id': '0E089bWgJvUl396T693rYg',
#    'alias': 'mercato-tomato-pie-newark',
#    'name': 'Mercato Tomato Pie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bn-1edtiYhTGivrf8tkcog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mercato-tomato-pie-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 288,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73486, 'longitude': -74.17068},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '212 Market St',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07102',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['212 Market St', 'Newark, NJ 07102']},
#    'phone': '+19734249000',
#    'display_phone': '(973) 424-9000',
#    'distance': 101.15684275311548},
#   {'id': 'mjVdcG2QpR3_Ww_gYP8yCg',
#    'alias': 'roberts-pizzeria-newark-3',
#    'name': "Robert's Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UyJu1aOs_LvLh0uBruTXBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roberts-pizzeria-newark-3?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 86,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7408097, 'longitude': -74.1723118},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '63 New St',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07102',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['63 New St', 'Newark, NJ 07102']},
#    'phone': '+19736420082',
#    'display_phone': '(973) 642-0082',
#    'distance': 616.4546799488285},
#   {'id': 'Oh5PRqcZxYN8yH4I0_xWJQ',
#    'alias': 'queen-pizza-ii-newark',
#    'name': 'Queen Pizza II',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/v5C5o03vWNsounepmNSBHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/queen-pizza-ii-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 22,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7362442016602,
#     'longitude': -74.1692657470703},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '48 Commerce St',
#     'address2': None,
#     'address3': None,
#     'city': 'Newark',
#     'zip_code': '07102',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['48 Commerce St', 'Newark, NJ 07102']},
#    'phone': '+19732421829',
#    'display_phone': '(973) 242-1829',
#    'distance': 235.0203744137755},
#   {'id': 'esNmc5qDddtI_Uzkb_yZYQ',
#    'alias': 'blaze-pizza-newark-2',
#    'name': 'Blaze Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/M4zzQ3DN9PBf_PGL3Qu53Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blaze-pizza-newark-2?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 217,
#    'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7382702827454,
#     'longitude': -74.1707014292479},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '691 Broad St',
#     'address2': None,
#     'address3': None,
#     'city': 'Newark',
#     'zip_code': '07102',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['691 Broad St', 'Newark, NJ 07102']},
#    'phone': '+19732064278',
#    'display_phone': '(973) 206-4278',
#    'distance': 357.9144778163163},
#   {'id': 'OQAUrJMdH7PIVp18dnBf_A',
#    'alias': 'mulberry-street-pizza-newark-3',
#    'name': 'Mulberry Street Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/s7ISvp2-2Hti3Mmw58DqBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mulberry-street-pizza-newark-3?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 32,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73003, 'longitude': -74.17154},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '258 Mulberry St',
#     'address2': None,
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07102',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['258 Mulberry St', 'Newark, NJ 07102']},
#    'phone': '+19735960275',
#    'display_phone': '(973) 596-0275',
#    'distance': 581.0791886078756},
#   {'id': 'lrcjZOeKsoEEZC57Li76lw',
#    'alias': 'pizzeria-sao-paulo-newark-2',
#    'name': 'Pizzeria Sao Paulo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ogIu4GyoNAvbBWPRd6a-Zw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizzeria-sao-paulo-newark-2?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 10,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.733443048625,
#     'longitude': -74.1634017974138},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '378 Market St',
#     'address2': '',
#     'address3': None,
#     'city': 'Newark',
#     'zip_code': '07105',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['378 Market St', 'Newark, NJ 07105']},
#    'phone': '+18622342211',
#    'display_phone': '(862) 234-2211',
#    'distance': 735.7720944833167},
#   {'id': 'K_DG6WJLam56T0LD8tP9Mw',
#    'alias': 'napoli-pizza-newark',
#    'name': 'Napoli Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eZMGFGqTdnwYxDEMqg31tw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/napoli-pizza-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 38,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7226964, 'longitude': -74.1642197},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '275 Chestnut St',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07105',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['275 Chestnut St', 'Newark, NJ 07105']},
#    'phone': '+19735221950',
#    'display_phone': '(973) 522-1950',
#    'distance': 1531.186176100313},
#   {'id': 'PyU9W_5ILfbZ8lVAG472aA',
#    'alias': 'queen-pizza-newark-2',
#    'name': 'Queen Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/js0a29m9oEl0RyQU6wPAUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/queen-pizza-newark-2?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 26,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7381554, 'longitude': -74.1723328},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '122 Halsey St',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07102',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['122 Halsey St', 'Newark, NJ 07102']},
#    'phone': '+19736247322',
#    'display_phone': '(973) 624-7322',
#    'distance': 333.38988472262344},
#   {'id': 'v_5uCu0L9iPTcVhXGEEG5g',
#    'alias': 'two-brothers-pizza-newark-3',
#    'name': 'Two Brothers Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CuU3KHROEY2HKeKzx-sOzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/two-brothers-pizza-newark-3?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 14,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.736366584897,
#     'longitude': -74.1707932949066},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '16 Clinton St',
#     'address2': None,
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07102',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['16 Clinton St', 'Newark, NJ 07102']},
#    'phone': '+19734977700',
#    'display_phone': '(973) 497-7700',
#    'distance': 150.4520878293786},
#   {'id': 'VarwdGR6_6Oo_F4Lrgytzw',
#    'alias': 'papa-pats-pizza-newark',
#    'name': "Papa Pat's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/od49cfdySx2R-yTfTgm1eg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/papa-pats-pizza-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 20,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.739252, 'longitude': -74.194761},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '263 S Orange Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Newark',
#     'zip_code': '07103',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['263 S Orange Ave', 'Newark, NJ 07103']},
#    'phone': '+19736227272',
#    'display_phone': '(973) 622-7272',
#    'distance': 1985.056497985956},
#   {'id': 'NHF7T9n4Kun8q7dznjnEPQ',
#    'alias': 'brazilian-pizza-newark',
#    'name': 'Brazilian Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/v7YFOHlLzad3iCZv9PXd-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brazilian-pizza-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 30,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72517, 'longitude': -74.15254},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '97 Wilson Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07105',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['97 Wilson Ave', 'Newark, NJ 07105']},
#    'phone': '+19738179400',
#    'display_phone': '(973) 817-9400',
#    'distance': 1972.1470355476647},
#   {'id': 'cSdcG_-5hQb9ID4rr5SWzQ',
#    'alias': 'dickie-dees-newark',
#    'name': "Dickie Dee's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PnLAcVq5wnk9lVVNzG02yQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dickie-dees-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 139,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76842, 'longitude': -74.18225},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '380 Bloomfield Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07107',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['380 Bloomfield Ave', 'Newark, NJ 07107']},
#    'phone': '+19734839396',
#    'display_phone': '(973) 483-9396',
#    'distance': 3786.6287679922348},
#   {'id': 'UrlJnjVMYF1GpKhKslobrw',
#    'alias': 'sabatinos-maplewood-2',
#    'name': "Sabatino's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KZ0jyEJ9iYw6qMJz805k0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sabatinos-maplewood-2?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 51,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7340131503814,
#     'longitude': -74.2696372661238},
#    'transactions': ['delivery'],
#    'location': {'address1': '513 Valley St',
#     'address2': '',
#     'address3': None,
#     'city': 'Maplewood',
#     'zip_code': '07040',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['513 Valley St', 'Maplewood, NJ 07040']},
#    'phone': '+19733279977',
#    'display_phone': '(973) 327-9977',
#    'distance': 8245.403277089825},
#   {'id': 'uXaFSGMLAeOjBbcbR96GPw',
#    'alias': 'tonys-pizzeria-newark',
#    'name': "Tony's Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/W9StuRIULKJ8VpfOc1D2Rg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tonys-pizzeria-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 114,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.72617, 'longitude': -74.16676},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '59 Pacific St',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07105',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['59 Pacific St', 'Newark, NJ 07105']},
#    'phone': '+19737321030',
#    'display_phone': '(973) 732-1030',
#    'distance': 1099.3650496447885},
#   {'id': '2bBl14HhMwTs7ShetuCPVQ',
#    'alias': 'pizza-village-cafe-newark',
#    'name': 'Pizza Village Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zM4PCf0xY21UbP7hSaF08g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizza-village-cafe-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 26,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.72761, 'longitude': -74.148717},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '311 Ferry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07105',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['311 Ferry St', 'Newark, NJ 07105']},
#    'phone': '+19733440707',
#    'display_phone': '(973) 344-0707',
#    'distance': 2123.0676185937673},
#   {'id': '0ptEblu2pBxavB2zajhjmw',
#    'alias': 'golden-pizzeria-newark',
#    'name': 'Golden Pizzeria',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nUUpAXLS-ALYr6Bi2YRyRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/golden-pizzeria-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 6,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7406921386719,
#     'longitude': -74.2012634277344},
#    'transactions': [],
#    'location': {'address1': '377 S Orange Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07103',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['377 S Orange Ave', 'Newark, NJ 07103']},
#    'phone': '+19736435003',
#    'display_phone': '(973) 643-5003',
#    'distance': 2552.5052566871473},
#   {'id': 'Kzj2GyqII6YUfDH8j0pmWw',
#    'alias': 'big-nicks-pizzeria-kearny',
#    'name': "Big Nick's Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5YeVzVOs94FGLJrB83j7MA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/big-nicks-pizzeria-kearny?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 43,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75569, 'longitude': -74.14868},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '72 Davis Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Kearny',
#     'zip_code': '07032',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['72 Davis Ave', 'Kearny, NJ 07032']},
#    'phone': '+12019988185',
#    'display_phone': '(201) 998-8185',
#    'distance': 2989.6413510901057},
#   {'id': 'eP_YBMmuNAR3omrndViSeg',
#    'alias': 'gencarellis-pizzeria-and-restaurant-newark-2',
#    'name': "Gencarelli's Pizzeria & Restaurant",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WfCmUW1CZK2Vqd5Yl6UKzA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gencarellis-pizzeria-and-restaurant-newark-2?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 68,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7724252, 'longitude': -74.1844515},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '501 Bloomfield Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07107',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['501 Bloomfield Ave', 'Newark, NJ 07107']},
#    'phone': '+19734816900',
#    'display_phone': '(973) 481-6900',
#    'distance': 4306.265769299229},
#   {'id': 'n8r0-2-DcuQOCtRjuHDUNQ',
#    'alias': 'ramons-pizza-and-wings-east-newark',
#    'name': "Ramon's Pizza and Wings",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KTYDUPwsdCZ78MB4WIbwbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramons-pizza-and-wings-east-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 4,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7353287111731,
#     'longitude': -74.1642580436702},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1 Raymond Plaza',
#     'address2': None,
#     'address3': None,
#     'city': 'East Newark',
#     'zip_code': '07102',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1 Raymond Plaza', 'East Newark, NJ 07102']},
#    'phone': '+19732423001',
#    'display_phone': '(973) 242-3001',
#    'distance': 618.2853045425971},
#   {'id': 'alW6CktqTwh7j4-3qThpdw',
#    'alias': 'francescas-pizza-and-pasta-newark',
#    'name': "Francesca's Pizza & Pasta",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ryYfqxeRG_MNWjlBEz9h-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/francescas-pizza-and-pasta-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 30,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7309069484472,
#     'longitude': -74.1653122007847},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '62 McWhorter St',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07105',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['62 McWhorter St', 'Newark, NJ 07105']},
#    'phone': '+19733449233',
#    'display_phone': '(973) 344-9233',
#    'distance': 750.1452445521081},
#   {'id': 'FRq0067Do1Evqo8rEi8IYw',
#    'alias': 'ninos-pizza-and-restaurant-harrison',
#    'name': "Nino's Pizza & Restaurant",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/slHFUWPd_HR1MR9lCkociw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ninos-pizza-and-restaurant-harrison?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 97,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7438178481254,
#     'longitude': -74.1543674118258},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '442 Bergen St',
#     'address2': '',
#     'address3': '',
#     'city': 'Harrison',
#     'zip_code': '07029',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['442 Bergen St', 'Harrison, NJ 07029']},
#    'phone': '+19734845770',
#    'display_phone': '(973) 484-5770',
#    'distance': 1748.2025063824926},
#   {'id': 'O_Fy58y3gzr3_usEWu9nlg',
#    'alias': 'ah-pizz-harrison-harrison',
#    'name': "Ah' Pizz - Harrison",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_3xeTd9cTGx_EqmaXcU2OA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ah-pizz-harrison-harrison?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 150,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.741156, 'longitude': -74.155954},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '615 Frank E Rodgers Blvd S',
#     'address2': '',
#     'address3': None,
#     'city': 'Harrison',
#     'zip_code': '07029',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['615 Frank E Rodgers Blvd S', 'Harrison, NJ 07029']},
#    'phone': '+19734859200',
#    'display_phone': '(973) 485-9200',
#    'distance': 1485.7015850721712},
#   {'id': 'I0X_zENB0uZGkAh_XJx-SA',
#    'alias': 'uptop-pizzeria-newark',
#    'name': 'Uptop Pizzeria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MGpJ8Va-88lzwaEoDCigfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uptop-pizzeria-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 51,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.6954667511555,
#     'longitude': -74.1735252661129},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': 'Newark Liberty International Airport - 3 Brewster Rd',
#     'address2': '',
#     'address3': 'Terminal C',
#     'city': 'Newark',
#     'zip_code': '07114',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['Newark Liberty International Airport - 3 Brewster Rd',
#      'Terminal C',
#      'Newark, NJ 07114']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4429.420841160204},
#   {'id': 'YdBYWAXAmLmDngZtQMcdfw',
#    'alias': 'ginas-pizzeria-harrison',
#    'name': "Gina's Pizzeria",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/k_aVlVBkG7V_hXmCXRIEEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginas-pizzeria-harrison?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 119,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.750228, 'longitude': -74.156868},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '503 Frank E Rodgers Blvd N',
#     'address2': '',
#     'address3': '',
#     'city': 'Harrison',
#     'zip_code': '07029',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['503 Frank E Rodgers Blvd N', 'Harrison, NJ 07029']},
#    'phone': '+19734824883',
#    'display_phone': '(973) 482-4883',
#    'distance': 2084.0731837697126},
#   {'id': '37ay-h_JmSBHQJD7cHM8NQ',
#    'alias': 'pizza-land-north-arlington-16',
#    'name': 'Pizza Land',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/s_kla08gAiYtj-GED59XIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizza-land-north-arlington-16?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 85,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.78173, 'longitude': -74.13793},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '260 Belleville Tpke',
#     'address2': '',
#     'address3': '',
#     'city': 'North Arlington',
#     'zip_code': '07031',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['260 Belleville Tpke', 'North Arlington, NJ 07031']},
#    'phone': '+12019982500',
#    'display_phone': '(201) 998-2500',
#    'distance': 5890.152949369317},
#   {'id': 'QC7l8xofILhqkIwWQOKpYQ',
#    'alias': 'queen-pizza-and-deli-newark',
#    'name': 'Queen Pizza & Deli',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RaG4xO4wqe8j6VWvlTl0Ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/queen-pizza-and-deli-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 13,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.73125, 'longitude': -74.17418},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '938 Broad St',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07102',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['938 Broad St', 'Newark, NJ 07102']},
#    'phone': '+19738021661',
#    'display_phone': '(973) 802-1661',
#    'distance': 490.7815807131364},
#   {'id': 'JkrXWzUQY3R7mxFL4Md-nQ',
#    'alias': 'star-tavern-orange',
#    'name': 'Star Tavern',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UyeJxgKXsfyeMyzBL59wGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/star-tavern-orange?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 825,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.783214, 'longitude': -74.225543},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '400 High St',
#     'address2': '',
#     'address3': '',
#     'city': 'Orange',
#     'zip_code': '07050',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['400 High St', 'Orange, NJ 07050']},
#    'phone': '+19736753336',
#    'display_phone': '(973) 675-3336',
#    'distance': 6993.249045620095},
#   {'id': 'eCHvjbjn1yH9zwl0hNHLHA',
#    'alias': 'pizza-town-newark-2',
#    'name': 'Pizza Town',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ua9KT_YuLnlnDZtVEwHMLA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizza-town-newark-2?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 15,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7827, 'longitude': -74.16165},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '883 Mt Prospect Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07104',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['883 Mt Prospect Ave', 'Newark, NJ 07104']},
#    'phone': '+19734835179',
#    'display_phone': '(973) 483-5179',
#    'distance': 5340.288912152167},
#   {'id': 'SxrpCtwVorqyAkh_a9siIg',
#    'alias': 'home-slice-pizza-kitchen-newark',
#    'name': 'HOME SLICE Pizza Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/I3jqprNnDhOlXM-gxbU_4w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/home-slice-pizza-kitchen-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.73418167, 'longitude': -74.16354667},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1 Raymond Plz W',
#     'address2': None,
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07102',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1 Raymond Plz W', 'Newark, NJ 07102']},
#    'phone': '+19738777700',
#    'display_phone': '(973) 877-7700',
#    'distance': 647.2188518077103},
#   {'id': 'al1QWbNaZMkpdExFevpMTw',
#    'alias': 'elis-pizza-pasta-elizabeth',
#    'name': "Eli's Pizza Pasta",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kEKWN0lRZy0T2Ew6NwT-fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elis-pizza-pasta-elizabeth?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 94,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wraps', 'title': 'Wraps'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.662972, 'longitude': -74.197951},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '766 Trumbull St',
#     'address2': '',
#     'address3': '',
#     'city': 'Elizabeth',
#     'zip_code': '07201',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['766 Trumbull St', 'Elizabeth, NJ 07201']},
#    'phone': '+19084360436',
#    'display_phone': '(908) 436-0436',
#    'distance': 8337.21662629265},
#   {'id': 'TQy5fLbcf0tKgUdTY5o--A',
#    'alias': 'pizza-2000-newark',
#    'name': 'Pizza 2000',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Cp-35Vp40nIyesI0twT0_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizza-2000-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 70,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.7309048, 'longitude': -74.1760158},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '19 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07102',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['19 Court St', 'Newark, NJ 07102']},
#    'phone': '+19736232300',
#    'display_phone': '(973) 623-2300',
#    'distance': 649.0116723150018},
#   {'id': 'CUdA5B3yAKcvvYMraV8PYg',
#    'alias': 'dominos-pizza-newark-11',
#    'name': "Domino's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9HyHizMvQGspz-NBS2bRrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dominos-pizza-newark-11?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 28,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 40.747875213623,
#     'longitude': -74.1912078857422},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '447 Central Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Newark',
#     'zip_code': '07107',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['447 Central Ave', 'Newark, NJ 07107']},
#    'phone': '+19732682700',
#    'display_phone': '(973) 268-2700',
#    'distance': 2153.895271963346},
#   {'id': '1PUdzukruPmPiZsoZcf-yA',
#    'alias': 'giovanni-pizza-pasta-and-grill-newark',
#    'name': 'Giovanni Pizza Pasta & Grill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xyc-CeYHvnYglSv1nkJcAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/giovanni-pizza-pasta-and-grill-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 68,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.7442963430172,
#     'longitude': -74.1780105495287},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '191 Central Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07103',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['191 Central Ave', 'Newark, NJ 07103']},
#    'phone': '+19737339400',
#    'display_phone': '(973) 733-9400',
#    'distance': 1131.260598277642},
#   {'id': 'rdunKiATzF9p2fKs9luQEQ',
#    'alias': 'bread-of-life-pao-da-vida-bakery-newark',
#    'name': 'Bread of Life Pao da Vida Bakery',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3NYkrcKaQO0bbSDfvMvFEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bread-of-life-pao-da-vida-bakery-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 15,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'brazilian', 'title': 'Brazilian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72188, 'longitude': -74.15835},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '331 Oliver St',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07105',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['331 Oliver St', 'Newark, NJ 07105']},
#    'phone': '+19738103594',
#    'display_phone': '(973) 810-3594',
#    'distance': 1880.5501814474042},
#   {'id': '1FUR_eH97s2pl7Q8_vw4bg',
#    'alias': 'bivio-panificio-montclair',
#    'name': 'Bivio Panificio',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/U7S2kEyCeMSYYi2ThdA2sw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bivio-panificio-montclair?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 82,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.81158, 'longitude': -74.20747},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '107 Pine St',
#     'address2': '',
#     'address3': None,
#     'city': 'Montclair',
#     'zip_code': '07042',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['107 Pine St', 'Montclair, NJ 07042']},
#    'phone': '+19739419602',
#    'display_phone': '(973) 941-9602',
#    'distance': 9002.328207611185},
#   {'id': 'IXBLE0MvRYJIczkdLvt2lA',
#    'alias': 'la-pizza-harrison',
#    'name': 'La Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/N9nIMtq2N3j-yRyNEAbG8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-pizza-harrison?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 38,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.746452331543,
#     'longitude': -74.1583633422852},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '240 Harrison Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Harrison',
#     'zip_code': '07029',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['240 Harrison Ave', 'Harrison, NJ 07029']},
#    'phone': '+19733501999',
#    'display_phone': '(973) 350-1999',
#    'distance': 1679.9588787191894},
#   {'id': '_keX6595cB4che-7CBI-ZQ',
#    'alias': 'dominos-pizza-newark-12',
#    'name': "Domino's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HW3UcC9iPpQYGazQ-v3VIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dominos-pizza-newark-12?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 23,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 40.70979, 'longitude': -74.2071},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1003 Bergen St',
#     'address2': None,
#     'address3': None,
#     'city': 'Newark',
#     'zip_code': '07112',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1003 Bergen St', 'Newark, NJ 07112']},
#    'phone': '+19739266000',
#    'display_phone': '(973) 926-6000',
#    'distance': 4106.113947440571},
#   {'id': 'UGzWwkFboQHmvtQJjuFQsQ',
#    'alias': 'dominos-pizza-newark-3',
#    'name': "Domino's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MNtO3neEWH5xHdPsQqmn3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dominos-pizza-newark-3?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 27,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 2.0,
#    'coordinates': {'latitude': 40.7267736643553,
#     'longitude': -74.1511031985283},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '51 Niagara St',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07105',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['51 Niagara St', 'Newark, NJ 07105']},
#    'phone': '+19733443033',
#    'display_phone': '(973) 344-3033',
#    'distance': 1983.8611953686775},
#   {'id': 'tbTdOf0tgKdNbm4eIAPsLQ',
#    'alias': 'luigis-italian-restaurant-newark',
#    'name': "Luigi's Italian Restaurant",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4SETgru0Yjb6SS7wYoe1gw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luigis-italian-restaurant-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 73,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77438, 'longitude': -74.18568},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '561 Bloomfield Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07107',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['561 Bloomfield Ave', 'Newark, NJ 07107']},
#    'phone': '+19734819696',
#    'display_phone': '(973) 481-9696',
#    'distance': 4503.991215854037},
#   {'id': '9SHMPOQ39ZPMJh5vau4xbQ',
#    'alias': 'mozzarella-south-orange',
#    'name': 'Mozzarella',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BuHgDvp5ErNjWYuh5f_eIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mozzarella-south-orange?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 56,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7391, 'longitude': -74.26429},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '396 Valley St',
#     'address2': None,
#     'address3': '',
#     'city': 'South Orange',
#     'zip_code': '07079',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['396 Valley St', 'South Orange, NJ 07079']},
#    'phone': '+19738215641',
#    'display_phone': '(973) 821-5641',
#    'distance': 7804.470081988862},
#   {'id': 'MgMPsNb2XwxfmA_9jvWckw',
#    'alias': 'belleville-pizza-belleville',
#    'name': 'Belleville Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/f-fM_gNBNHsU29lRNQd21g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/belleville-pizza-belleville?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 91,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7862280544507,
#     'longitude': -74.1529441474569},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '145 Washington Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Belleville',
#     'zip_code': '07109',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['145 Washington Ave', 'Belleville, NJ 07109']},
#    'phone': '+19738440001',
#    'display_phone': '(973) 844-0001',
#    'distance': 5883.360280528056},
#   {'id': 'Kb8i3ZKJbKk_dQoVB7s9oA',
#    'alias': 'franks-pizzeria-newark',
#    'name': "Frank's Pizzeria",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JgkKxEp8KF4qDkhh3G56Vw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/franks-pizzeria-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 34,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.75904, 'longitude': -74.17526},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '161 Bloomfield Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07104',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['161 Bloomfield Ave', 'Newark, NJ 07104']},
#    'phone': '+19734828891',
#    'display_phone': '(973) 482-8891',
#    'distance': 2657.7091630497453},
#   {'id': 'alyUkpVVyyrdOYxRGFO1UA',
#    'alias': 'pizzanada-bloomfield',
#    'name': 'Pizzanada',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gkUi4K875ZTEV50mY_AcDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizzanada-bloomfield?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 42,
#    'categories': [{'alias': 'empanadas', 'title': 'Empanadas'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.79272, 'longitude': -74.185544},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '128 Montgomery St',
#     'address2': '',
#     'address3': '',
#     'city': 'Bloomfield',
#     'zip_code': '07003',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['128 Montgomery St', 'Bloomfield, NJ 07003']},
#    'phone': '+19739008668',
#    'display_phone': '(973) 900-8668',
#    'distance': 6491.393891605948},
#   {'id': 'KE9btlMu1BUpGnskAgFMag',
#    'alias': 'urban-bricks-pizza-kearny',
#    'name': 'Urban Bricks Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MXOWhrCYwEXaRU5sWwvN5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/urban-bricks-pizza-kearny?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 57,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.759322, 'longitude': -74.1604882},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '190 Passaic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Kearny',
#     'zip_code': '07032',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['190 Passaic Ave', 'Kearny, NJ 07032']},
#    'phone': '+15512748000',
#    'display_phone': '(551) 274-8000',
#    'distance': 2901.6098065899305},
#   {'id': '0OPFbtnLmQxNoao1ocO57g',
#    'alias': 'marios-pizza-restaurant-newark',
#    'name': "Mario's Pizza Restaurant",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uJY9lmE9AdeF2vFXYTxRWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marios-pizza-restaurant-newark?adjust_creative=ZQN04nb35I8POvxDUBa6Kg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ZQN04nb35I8POvxDUBa6Kg',
#    'review_count': 12,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7569438, 'longitude': -74.1669916},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1413 McCarter Hwy',
#     'address2': None,
#     'address3': None,
#     'city': 'Newark',
#     'zip_code': '07104',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['1413 McCarter Hwy', 'Newark, NJ 07104']},
#    'phone': '+19734972031',
#    'display_phone': '(973) 497-2031',
#    'distance': 2436.610278572847}],
#  'total': 544,
#  'region': {'center': {'longitude': -74.17179107666016,
#    'latitude': 40.735279841425196}}}

# %%
# cleaning and exploring the data
for pizza_places in pizza.keys():
    print(pizza_places)
# Out:
# businesses
# total
# region

# %%
# explore which objects in the dataframe we need

pizza_df = pd.DataFrame.from_dict(pizza['businesses'])

pizza_df.head()
# Out:
#                        id                           alias  \
# 0  0E089bWgJvUl396T693rYg       mercato-tomato-pie-newark
# 1  mjVdcG2QpR3_Ww_gYP8yCg       roberts-pizzeria-newark-3
# 2  Oh5PRqcZxYN8yH4I0_xWJQ           queen-pizza-ii-newark
# 3  esNmc5qDddtI_Uzkb_yZYQ            blaze-pizza-newark-2
# 4  OQAUrJMdH7PIVp18dnBf_A  mulberry-street-pizza-newark-3
#
#                     name                                          image_url  \
# 0     Mercato Tomato Pie  https://s3-media1.fl.yelpcdn.com/bphoto/bn-1ed...
# 1      Robert's Pizzeria  https://s3-media2.fl.yelpcdn.com/bphoto/UyJu1a...
# 2         Queen Pizza II  https://s3-media2.fl.yelpcdn.com/bphoto/v5C5o0...
# 3            Blaze Pizza  https://s3-media4.fl.yelpcdn.com/bphoto/M4zzQ3...
# 4  Mulberry Street Pizza  https://s3-media2.fl.yelpcdn.com/bphoto/s7ISvp...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/mercato-tomato-pie-ne...           288
# 1      False  https://www.yelp.com/biz/roberts-pizzeria-newa...            86
# 2      False  https://www.yelp.com/biz/queen-pizza-ii-newark...            22
# 3      False  https://www.yelp.com/biz/blaze-pizza-newark-2?...           217
# 4      False  https://www.yelp.com/biz/mulberry-street-pizza...            32
#
#                                           categories  rating  \
# 0  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 1  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 2  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# 3  [{'alias': 'salad', 'title': 'Salad'}, {'alias...     4.0
# 4  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.5
#
#                                          coordinates        transactions  \
# 0     {'latitude': 40.73486, 'longitude': -74.17068}  [delivery, pickup]
# 1  {'latitude': 40.7408097, 'longitude': -74.1723...  [delivery, pickup]
# 2  {'latitude': 40.7362442016602, 'longitude': -7...  [delivery, pickup]
# 3  {'latitude': 40.7382702827454, 'longitude': -7...                  []
# 4     {'latitude': 40.73003, 'longitude': -74.17154}  [delivery, pickup]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '212 Market St', 'address2': '', ...  +19734249000
# 1     $  {'address1': '63 New St', 'address2': '', 'add...  +19736420082
# 2     $  {'address1': '48 Commerce St', 'address2': Non...  +19732421829
# 3     $  {'address1': '691 Broad St', 'address2': None,...  +19732064278
# 4   NaN  {'address1': '258 Mulberry St', 'address2': No...  +19735960275
#
#     display_phone    distance
# 0  (973) 424-9000  101.156843
# 1  (973) 642-0082  616.454680
# 2  (973) 242-1829  235.020374
# 3  (973) 206-4278  357.914478
# 4  (973) 596-0275  581.079189

# %%
# let's turn the things we need into a pandas dataframe

# %%
# you can do some analysis and visualization from here on! 

# visualize the review count - what's the appropriate plot?
plt.hist(pizza_df['review_count'])
# Out:
# (array([34.,  8.,  1.,  1.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([  3. ,  85.2, 167.4, 249.6, 331.8, 414. , 496.2, 578.4, 660.6,
#         742.8, 825. ]),
#  <a list of 10 Patch objects>)

# %%
# query the name of the axe throwing place with the highest review
pizza_df.plot('rating','review_count',kind='scatter')
# look into geopandas

import geopandas as gpd
import geoplot
from shaply.geometry import Point, Polygon
geometry = [Point(x,y) for xy in zip(pizza_df['Lon'])]
gdf = gpd.GeoDataFrame(
    pizza_df, geometry=geopandas.points_from_xy(df.Longitude, df.Latitude))

# %%
# migrate the cleaned data into a sql db

# %%
# can you do some other queries using sql/pandas?

# %% [markdown]
# #### Resources
# - [Getting Data from Reddit API](https://www.storybench.org/how-to-scrape-reddit-with-python/)
# - [Twitch API](https://dev.twitch.tv/docs)
